# %% [markdown]
# # Understanding the covariance matrix
#
# From [datascienceplus](https://datascienceplus.com/understanding-the-covariance-matrix/)

# %%
import numpy as np

# %%
# epochs × channels × samples
epochs = 5 # 5 epochs of 1 seg each
channels = 5 # Insight
samples = 10 # 10Hz
X = np.random.rand(epochs, channels, samples)
X
# Out:
# array([[[0.87506525, 0.92668936, 0.48761751, 0.80503188, 0.64977121,
#          0.02361411, 0.47703148, 0.38168045, 0.61226372, 0.63426182],
#         [0.80116171, 0.69034961, 0.63478763, 0.60725162, 0.9294596 ,
#          0.2800921 , 0.02384113, 0.96665063, 0.95299218, 0.60379116],
#         [0.32752528, 0.03422233, 0.36184146, 0.10856838, 0.28859274,
#          0.24595204, 0.56791653, 0.25495439, 0.07541473, 0.36940002],
#         [0.23748875, 0.78490276, 0.40168534, 0.8732537 , 0.48326064,
#          0.01447895, 0.73344981, 0.81017685, 0.05101574, 0.99417339],
#         [0.89312236, 0.70902808, 0.49620705, 0.13672928, 0.81396526,
#          0.47518589, 0.10217577, 0.89081159, 0.27296429, 0.73063392]],
#
#        [[0.06427235, 0.10156965, 0.4871098 , 0.58170893, 0.51230045,
#          0.00242972, 0.06898193, 0.31197642, 0.26846222, 0.23859257],
#         [0.85088911, 0.92596533, 0.80476682, 0.36226742, 0.48612749,
# ...
