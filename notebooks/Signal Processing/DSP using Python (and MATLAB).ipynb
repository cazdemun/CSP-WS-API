# %% [markdown]
# # Digital Signal Processing
#
# Taken from: https://www.youtube.com/playlist?list=PLd9J3wW9xxHuCqfNxZ4xOk2debNAArWzG

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci
import sympy as sm

# %% [markdown]
# ## L01: Introduction to Digital Signals
#
# ### Definition
#
# What are signals?;anything that carries information/data
#
# signals examples:
#
# audio signals (1-D signals x(t)),
#
# images, x-ray images (2-D signals),
#
# other dimensions
#
# Signal representation:
#
# x(t),
#
# I(x,y)
#
#
# ### Examples of 1D signal
#
# $$ x(t) = t^2 + 4t + 1 $$
# $$ x(t) = sin(wt) $$

# %%
def x(t):
    return t**2 + 4 * t+ 1

X = [x for x in range(1000)]
Y = [x_1(t) for t in range(1000)]

plt.plot(X, Y)
plt.show()

# %%
from math import sin

def x(t):
    # mientras mas alta la frecuencia, más "apachurrada" estará la señal
    # mientras mas baja la frecuencia, más "esparcida" estará la señal
    w = 0.01
    return sin(w * t)

X = [x for x in range(10000)]
Y = [x(t) for t in range(10000)]

plt.plot(X, Y)
plt.show()

# %% [markdown]
# ### Types of signal
#
# analog;potential infinite amplitude
#
# continuous;every instance of time
#
# real life signals nature;continuous time
#
# discrete;
#
# digital;amplitud only posibles values are 0 or 1
#
# domains;domains are just the axis
#
# ### Sampling
#
# discretization;reducing an infinite domain (like time) to specific time points
#
# sampling period T; gap between time points in discrete time signals
#
# K sample of discrete signal to continuous signal; $x[k] = x[Tk]$
#
# sampling theorem;https://www.youtube.com/watch?v=iQaFDpiNOlA
#
# sampling theorem; $F_s = 2F_m$
#
# sampling theorem ELI5; if we decompose the signal, we'll get one with a maximum frequency (squished signal). The sampling frequency (every time point we choose) must be twice of that at minimum

# %% [markdown]
# ### Analog to Digital conversion
#
# Sampler -> Quantizer -> Coder

# %% [markdown]
# ### Quantizer
#
# world length;how much digital bits (n) are going to be used
#
# step size;space between values -> max voltage|value (assuming we start at 0) / number of steps
#
# number of steps; max voltage|value / 2^n - 1 (?)

# %% [markdown]
# ### Coder
#
# didnt understand, how a value is stored?

# %% [markdown]
# ### digital to analog converter
#
# device?
#
# $$analog_value = V_{ref}(\frac{a_0}{2} + \frac{a_1}{4} + \frac{a_2}{8} + ... )$$
#
# where $a_n$ is the bit on

# %% [markdown]
# Digital Sequence Representation
#
# $$x(t)\rightarrow x[nT]$$
